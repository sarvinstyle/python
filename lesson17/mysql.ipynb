# %%
import pymysql
import pandas as pd

connection = pymysql.connect(
    host ='localhost',
    user = 'root',
    passwd= '2314',
    database= 'sakila'
)

# try:
#     with connection.cursor() as cursor:
#         cursor.execute('select * from actor')
#         result = cursor.fetchall()
#         result = pd.DataFrame(result)
#         print(result)

# finally :
#     connection.close()

# %%
# try:   
#     with connection.cursor() as cursor:
#         sql = "insert into actor (first_name , last_name , last_update) values (%s , %s , %s)"
#         cursor.execute(sql , ('reza' , 'alizadeh' , '2006-02-15 04:34:33'))
#         connection.commit()
#         print("new actor is inserted")
# finally :
#     connection.close()

# %%
# try:   
#     with connection.cursor() as cursor:
#        sql = "update actor set first_name = %s , last_name = %s where actor_id = 201"
#        cursor.execute(sql, ("mina" , "rezai"))
#        connection.commit()
#        print("successfully updated")
# finally :
#     connection.close()

# %%
# try:   
#     with connection.cursor() as cursor:
#         sql = "delete from actor where actor_id = %s"
#         cursor.execute(sql , (201,))
#         connection.commit()
#         print("successfully deleted")
# finally :
#     connection.close()

# %%
try:   
    with connection.cursor() as cursor:
        cursor.callproc('get_actors',[30])
        result = cursor.fetchall()
        print(result)
finally :
    connection.close()
# Out:
# ((1, 'PENELOPE', 'GUINESS', datetime.datetime(2006, 2, 15, 4, 34, 33)), (2, 'NICK', 'WAHLBERG', datetime.datetime(2006, 2, 15, 4, 34, 33)), (3, 'ED', 'CHASE', datetime.datetime(2006, 2, 15, 4, 34, 33)), (4, 'JENNIFER', 'DAVIS', datetime.datetime(2006, 2, 15, 4, 34, 33)), (5, 'JOHNNY', 'LOLLOBRIGIDA', datetime.datetime(2006, 2, 15, 4, 34, 33)), (6, 'BETTE', 'NICHOLSON', datetime.datetime(2006, 2, 15, 4, 34, 33)), (7, 'GRACE', 'MOSTEL', datetime.datetime(2006, 2, 15, 4, 34, 33)), (8, 'MATTHEW', 'JOHANSSON', datetime.datetime(2006, 2, 15, 4, 34, 33)), (9, 'JOE', 'SWANK', datetime.datetime(2006, 2, 15, 4, 34, 33)), (10, 'CHRISTIAN', 'GABLE', datetime.datetime(2006, 2, 15, 4, 34, 33)), (11, 'ZERO', 'CAGE', datetime.datetime(2006, 2, 15, 4, 34, 33)), (12, 'KARL', 'BERRY', datetime.datetime(2006, 2, 15, 4, 34, 33)), (13, 'UMA', 'WOOD', datetime.datetime(2006, 2, 15, 4, 34, 33)), (14, 'VIVIEN', 'BERGEN', datetime.datetime(2006, 2, 15, 4, 34, 33)), (15, 'CUBA', 'OLIVIER', datetime.datetime(20
# ...
